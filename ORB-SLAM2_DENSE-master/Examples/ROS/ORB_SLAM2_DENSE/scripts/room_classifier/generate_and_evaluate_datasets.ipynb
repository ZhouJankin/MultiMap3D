# %%
##
# This module will create multiple data sets using room_labels_and_features_generator.py and then
# train SVCs on those data sets using room_classifier.py and collect the accuracies.
##

from room_classifier import RoomClassifier
from room_labels_and_features_generator import RoomClassifierTrainingDataGenerator
from ModelType import ModelType

import matplotlib.pyplot as plt
import numpy as np

# how many volumes do we want? We will increase each volume by 100. So if we want datasets of 
# size [100, 200, 300] then this should be 3.
number_of_dataset_volumes = 12

# How many times we will re-generate data set with each volume? So if this was 5, 
# and number_of_dataset_volumes = 3 then we would generate 5 data sets for each volume
# of sizes [100, 200, 300] and we would get 15 tests altogether.
number_of_tests_per_dataset_volume = 100

# We'll create an empty Numpy array and put the our SVC accuracies into there.
dataset_test_results = np.zeros(shape=(number_of_dataset_volumes, number_of_tests_per_dataset_volume))
print(dataset_test_results.shape)

for volume in range(number_of_dataset_volumes):
    accuracies = []
    for test in range(number_of_tests_per_dataset_volume):
        gen = RoomClassifierTrainingDataGenerator(ModelType.FEATURES_12, (volume + 1) * 100)
        rc = RoomClassifier(True, ModelType.FEATURES_12)
        accuracies.append(rc.getAccuracy())
    dataset_test_results[volume] = accuracies

#print(dataset_test_results)
fig, ax = plt.subplots()
ax.axes.get_xaxis().set_visible(False)
#ax7.set_title("Variance while " + operation + " " + gesture + " gesture")
ax.set_title(ModelType.FEATURES_12.name)
ax.boxplot(dataset_test_results)
plt.show()
# Out:
# (20, 200)
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.7
# Predicted Class for Elem 3: bedroom  Class for Elem 8: living_room  Class for elem 5: bedroom
# Real Class for Elem 3: living_room  Real Class for Elem 8: living_room  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.7
# Predicted Class for Elem 3: study  Class for Elem 8: bathroom  Class for elem 5: study
# Real Class for Elem 3: bedroom  Real Class for Elem 8: bathroom  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: bedroom  Class for Elem 8: study  Class for elem 5: living_room
# Real Class for Elem 3: bedroom  Real Class for Elem 8: study  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.002 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: bathroom  Class for Elem 8: living_room  Class for elem 5: bedroom
# Real Class for Elem 3: bathroom  Real Class for Elem 8: living_room  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  1.0
# Predicted Class for Elem 3: study  Class for Elem 8: living_room  Class for elem 5: living_room
# Real Class for Elem 3: study  Real Class for Elem 8: living_room  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: study  Class for Elem 8: bathroom  Class for elem 5: study
# Real Class for Elem 3: study  Real Class for Elem 8: bathroom  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: study  Class for Elem 8: bedroom  Class for elem 5: bathroom
# Real Class for Elem 3: study  Real Class for Elem 8: bedroom  Real Class for elem 5: bathroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.5
# Predicted Class for Elem 3: bedroom  Class for Elem 8: bathroom  Class for elem 5: living_room
# Real Class for Elem 3: study  Real Class for Elem 8: bathroom  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: living_room  Class for Elem 8: bathroom  Class for elem 5: study
# Real Class for Elem 3: living_room  Real Class for Elem 8: bathroom  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: living_room  Class for Elem 8: bathroom  Class for elem 5: living_room
# Real Class for Elem 3: living_room  Real Class for Elem 8: bathroom  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: bedroom  Class for Elem 8: living_room  Class for elem 5: study
# Real Class for Elem 3: bedroom  Real Class for Elem 8: living_room  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: bedroom  Class for Elem 8: living_room  Class for elem 5: study
# Real Class for Elem 3: bedroom  Real Class for Elem 8: living_room  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: bathroom  Class for Elem 8: bedroom  Class for elem 5: living_room
# Real Class for Elem 3: bathroom  Real Class for Elem 8: bedroom  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  1.0
# Predicted Class for Elem 3: bedroom  Class for Elem 8: study  Class for elem 5: bedroom
# Real Class for Elem 3: bedroom  Real Class for Elem 8: study  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: bedroom  Class for Elem 8: bedroom  Class for elem 5: living_room
# Real Class for Elem 3: bedroom  Real Class for Elem 8: bedroom  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.7
# Predicted Class for Elem 3: bathroom  Class for Elem 8: bedroom  Class for elem 5: study
# Real Class for Elem 3: bathroom  Real Class for Elem 8: living_room  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  1.0
# Predicted Class for Elem 3: living_room  Class for Elem 8: study  Class for elem 5: living_room
# Real Class for Elem 3: living_room  Real Class for Elem 8: study  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: study  Class for Elem 8: living_room  Class for elem 5: bathroom
# Real Class for Elem 3: study  Real Class for Elem 8: living_room  Real Class for elem 5: bathroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: study  Class for Elem 8: bedroom  Class for elem 5: study
# Real Class for Elem 3: study  Real Class for Elem 8: living_room  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  1.0
# Predicted Class for Elem 3: living_room  Class for Elem 8: study  Class for elem 5: living_room
# Real Class for Elem 3: living_room  Real Class for Elem 8: study  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: bathroom  Class for Elem 8: bathroom  Class for elem 5: living_room
# Real Class for Elem 3: bathroom  Real Class for Elem 8: bathroom  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: living_room  Class for Elem 8: study  Class for elem 5: living_room
# Real Class for Elem 3: living_room  Real Class for Elem 8: study  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: bedroom  Class for Elem 8: study  Class for elem 5: bedroom
# Real Class for Elem 3: living_room  Real Class for Elem 8: study  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: bedroom  Class for Elem 8: study  Class for elem 5: bedroom
# Real Class for Elem 3: study  Real Class for Elem 8: study  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: study  Class for Elem 8: study  Class for elem 5: study
# Real Class for Elem 3: study  Real Class for Elem 8: study  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  1.0
# Predicted Class for Elem 3: study  Class for Elem 8: bedroom  Class for elem 5: study
# Real Class for Elem 3: study  Real Class for Elem 8: bedroom  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: bathroom  Class for Elem 8: bedroom  Class for elem 5: study
# Real Class for Elem 3: bathroom  Real Class for Elem 8: bedroom  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  1.0
# Predicted Class for Elem 3: study  Class for Elem 8: study  Class for elem 5: bathroom
# Real Class for Elem 3: study  Real Class for Elem 8: study  Real Class for elem 5: bathroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  1.0
# Predicted Class for Elem 3: study  Class for Elem 8: bathroom  Class for elem 5: bathroom
# Real Class for Elem 3: study  Real Class for Elem 8: bathroom  Real Class for elem 5: bathroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  1.0
# Predicted Class for Elem 3: study  Class for Elem 8: bedroom  Class for elem 5: bathroom
# Real Class for Elem 3: study  Real Class for Elem 8: bedroom  Real Class for elem 5: bathroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.7
# Predicted Class for Elem 3: living_room  Class for Elem 8: study  Class for elem 5: bedroom
# Real Class for Elem 3: bedroom  Real Class for Elem 8: study  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: study  Class for Elem 8: bedroom  Class for elem 5: bathroom
# Real Class for Elem 3: bedroom  Real Class for Elem 8: bedroom  Real Class for elem 5: bathroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.7
# Predicted Class for Elem 3: study  Class for Elem 8: bathroom  Class for elem 5: bedroom
# Real Class for Elem 3: study  Real Class for Elem 8: bathroom  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: bathroom  Class for Elem 8: bedroom  Class for elem 5: study
# Real Class for Elem 3: bathroom  Real Class for Elem 8: bedroom  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  1.0
# Predicted Class for Elem 3: living_room  Class for Elem 8: bathroom  Class for elem 5: study
# Real Class for Elem 3: living_room  Real Class for Elem 8: bathroom  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.7
# Predicted Class for Elem 3: study  Class for Elem 8: bathroom  Class for elem 5: study
# Real Class for Elem 3: study  Real Class for Elem 8: bathroom  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  1.0
# Predicted Class for Elem 3: bathroom  Class for Elem 8: bedroom  Class for elem 5: bedroom
# Real Class for Elem 3: bathroom  Real Class for Elem 8: bedroom  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  1.0
# Predicted Class for Elem 3: bathroom  Class for Elem 8: study  Class for elem 5: bedroom
# Real Class for Elem 3: bathroom  Real Class for Elem 8: study  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: living_room  Class for Elem 8: study  Class for elem 5: living_room
# Real Class for Elem 3: living_room  Real Class for Elem 8: study  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: living_room  Class for Elem 8: bathroom  Class for elem 5: bathroom
# Real Class for Elem 3: living_room  Real Class for Elem 8: bathroom  Real Class for elem 5: bathroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: bedroom  Class for Elem 8: bathroom  Class for elem 5: living_room
# Real Class for Elem 3: bedroom  Real Class for Elem 8: bathroom  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: living_room  Class for Elem 8: study  Class for elem 5: bathroom
# Real Class for Elem 3: living_room  Real Class for Elem 8: study  Real Class for elem 5: bathroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: living_room  Class for Elem 8: bedroom  Class for elem 5: study
# Real Class for Elem 3: bedroom  Real Class for Elem 8: bedroom  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  1.0
# Predicted Class for Elem 3: living_room  Class for Elem 8: bathroom  Class for elem 5: bathroom
# Real Class for Elem 3: living_room  Real Class for Elem 8: bathroom  Real Class for elem 5: bathroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: bedroom  Class for Elem 8: bathroom  Class for elem 5: study
# Real Class for Elem 3: bedroom  Real Class for Elem 8: bathroom  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: living_room  Class for Elem 8: bedroom  Class for elem 5: study
# Real Class for Elem 3: living_room  Real Class for Elem 8: living_room  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.7
# Predicted Class for Elem 3: bedroom  Class for Elem 8: study  Class for elem 5: bedroom
# Real Class for Elem 3: living_room  Real Class for Elem 8: study  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: study  Class for Elem 8: bathroom  Class for elem 5: bedroom
# Real Class for Elem 3: living_room  Real Class for Elem 8: bathroom  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  1.0
# Predicted Class for Elem 3: living_room  Class for Elem 8: study  Class for elem 5: study
# Real Class for Elem 3: living_room  Real Class for Elem 8: study  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.7
# Predicted Class for Elem 3: study  Class for Elem 8: bathroom  Class for elem 5: study
# Real Class for Elem 3: bedroom  Real Class for Elem 8: bathroom  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: study  Class for Elem 8: study  Class for elem 5: bedroom
# Real Class for Elem 3: study  Real Class for Elem 8: study  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.002 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: living_room  Class for Elem 8: bedroom  Class for elem 5: study
# Real Class for Elem 3: study  Real Class for Elem 8: bedroom  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  1.0
# Predicted Class for Elem 3: study  Class for Elem 8: study  Class for elem 5: bedroom
# Real Class for Elem 3: study  Real Class for Elem 8: study  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  1.0
# Predicted Class for Elem 3: study  Class for Elem 8: bathroom  Class for elem 5: bedroom
# Real Class for Elem 3: study  Real Class for Elem 8: bathroom  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: study  Class for Elem 8: bathroom  Class for elem 5: study
# Real Class for Elem 3: study  Real Class for Elem 8: bathroom  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.002 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  1.0
# Predicted Class for Elem 3: study  Class for Elem 8: living_room  Class for elem 5: bedroom
# Real Class for Elem 3: study  Real Class for Elem 8: living_room  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: living_room  Class for Elem 8: study  Class for elem 5: living_room
# Real Class for Elem 3: living_room  Real Class for Elem 8: study  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: living_room  Class for Elem 8: living_room  Class for elem 5: study
# Real Class for Elem 3: bedroom  Real Class for Elem 8: living_room  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.002 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: bedroom  Class for Elem 8: bedroom  Class for elem 5: living_room
# Real Class for Elem 3: bedroom  Real Class for Elem 8: bedroom  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: study  Class for Elem 8: bedroom  Class for elem 5: bedroom
# Real Class for Elem 3: study  Real Class for Elem 8: bedroom  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  1.0
# Predicted Class for Elem 3: bedroom  Class for Elem 8: living_room  Class for elem 5: living_room
# Real Class for Elem 3: bedroom  Real Class for Elem 8: living_room  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  1.0
# Predicted Class for Elem 3: bathroom  Class for Elem 8: bathroom  Class for elem 5: bathroom
# Real Class for Elem 3: bathroom  Real Class for Elem 8: bathroom  Real Class for elem 5: bathroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: living_room  Class for Elem 8: living_room  Class for elem 5: study
# Real Class for Elem 3: living_room  Real Class for Elem 8: living_room  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: bedroom  Class for Elem 8: bathroom  Class for elem 5: bedroom
# Real Class for Elem 3: bedroom  Real Class for Elem 8: bathroom  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.7
# Predicted Class for Elem 3: living_room  Class for Elem 8: study  Class for elem 5: bathroom
# Real Class for Elem 3: living_room  Real Class for Elem 8: living_room  Real Class for elem 5: bathroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: living_room  Class for Elem 8: study  Class for elem 5: study
# Real Class for Elem 3: living_room  Real Class for Elem 8: study  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.7
# Predicted Class for Elem 3: living_room  Class for Elem 8: bathroom  Class for elem 5: bedroom
# Real Class for Elem 3: bedroom  Real Class for Elem 8: bathroom  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  1.0
# Predicted Class for Elem 3: bedroom  Class for Elem 8: study  Class for elem 5: living_room
# Real Class for Elem 3: bedroom  Real Class for Elem 8: study  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: study  Class for Elem 8: bathroom  Class for elem 5: bedroom
# Real Class for Elem 3: study  Real Class for Elem 8: bathroom  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: bathroom  Class for Elem 8: living_room  Class for elem 5: study
# Real Class for Elem 3: bathroom  Real Class for Elem 8: living_room  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: bathroom  Class for Elem 8: bathroom  Class for elem 5: living_room
# Real Class for Elem 3: bathroom  Real Class for Elem 8: bathroom  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.7
# Predicted Class for Elem 3: study  Class for Elem 8: living_room  Class for elem 5: bedroom
# Real Class for Elem 3: bedroom  Real Class for Elem 8: living_room  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: study  Class for Elem 8: bathroom  Class for elem 5: study
# Real Class for Elem 3: living_room  Real Class for Elem 8: bathroom  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.6
# Predicted Class for Elem 3: bathroom  Class for Elem 8: bathroom  Class for elem 5: bedroom
# Real Class for Elem 3: bathroom  Real Class for Elem 8: bathroom  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: bedroom  Class for Elem 8: living_room  Class for elem 5: study
# Real Class for Elem 3: bedroom  Real Class for Elem 8: living_room  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: bedroom  Class for Elem 8: bedroom  Class for elem 5: bathroom
# Real Class for Elem 3: bedroom  Real Class for Elem 8: bedroom  Real Class for elem 5: bathroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.6
# Predicted Class for Elem 3: living_room  Class for Elem 8: living_room  Class for elem 5: bedroom
# Real Class for Elem 3: living_room  Real Class for Elem 8: living_room  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: study  Class for Elem 8: bedroom  Class for elem 5: bathroom
# Real Class for Elem 3: living_room  Real Class for Elem 8: bedroom  Real Class for elem 5: bathroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: study  Class for Elem 8: study  Class for elem 5: bedroom
# Real Class for Elem 3: study  Real Class for Elem 8: study  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: bedroom  Class for Elem 8: living_room  Class for elem 5: study
# Real Class for Elem 3: bedroom  Real Class for Elem 8: bedroom  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: study  Class for Elem 8: bedroom  Class for elem 5: study
# Real Class for Elem 3: study  Real Class for Elem 8: bedroom  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: bathroom  Class for Elem 8: bathroom  Class for elem 5: bedroom
# Real Class for Elem 3: bathroom  Real Class for Elem 8: bathroom  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: bathroom  Class for Elem 8: bedroom  Class for elem 5: living_room
# Real Class for Elem 3: bathroom  Real Class for Elem 8: bedroom  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: bathroom  Class for Elem 8: bedroom  Class for elem 5: living_room
# Real Class for Elem 3: bathroom  Real Class for Elem 8: bedroom  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: study  Class for Elem 8: bedroom  Class for elem 5: study
# Real Class for Elem 3: study  Real Class for Elem 8: bedroom  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: study  Class for Elem 8: bedroom  Class for elem 5: study
# Real Class for Elem 3: study  Real Class for Elem 8: bedroom  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: living_room  Class for Elem 8: bathroom  Class for elem 5: bathroom
# Real Class for Elem 3: living_room  Real Class for Elem 8: bathroom  Real Class for elem 5: bathroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  1.0
# Predicted Class for Elem 3: study  Class for Elem 8: study  Class for elem 5: study
# Real Class for Elem 3: study  Real Class for Elem 8: study  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: living_room  Class for Elem 8: study  Class for elem 5: study
# Real Class for Elem 3: living_room  Real Class for Elem 8: study  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  1.0
# Predicted Class for Elem 3: living_room  Class for Elem 8: bathroom  Class for elem 5: study
# Real Class for Elem 3: living_room  Real Class for Elem 8: bathroom  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: study  Class for Elem 8: study  Class for elem 5: living_room
# Real Class for Elem 3: study  Real Class for Elem 8: study  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.8
# Predicted Class for Elem 3: living_room  Class for Elem 8: study  Class for elem 5: bedroom
# Real Class for Elem 3: living_room  Real Class for Elem 8: study  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: living_room  Class for Elem 8: bedroom  Class for elem 5: bathroom
# Real Class for Elem 3: living_room  Real Class for Elem 8: bedroom  Real Class for elem 5: bathroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.5
# Predicted Class for Elem 3: living_room  Class for Elem 8: study  Class for elem 5: study
# Real Class for Elem 3: bedroom  Real Class for Elem 8: study  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 100
# Stored 100 samples for FEATURES_12
# (90, 10)
# (10, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.001 s
# prediction time: 0.0 s
# accuracy calculation time: 0.0 s
# Accuracy =  1.0
# ...
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.017 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.905
# Predicted Class for Elem 3: study  Class for Elem 8: living_room  Class for elem 5: study
# Real Class for Elem 3: study  Real Class for Elem 8: living_room  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.021 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.895
# Predicted Class for Elem 3: bedroom  Class for Elem 8: study  Class for elem 5: bedroom
# Real Class for Elem 3: bedroom  Real Class for Elem 8: study  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.016 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.87
# Predicted Class for Elem 3: bathroom  Class for Elem 8: bathroom  Class for elem 5: bedroom
# Real Class for Elem 3: bathroom  Real Class for Elem 8: bathroom  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.019 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.945
# Predicted Class for Elem 3: bathroom  Class for Elem 8: study  Class for elem 5: study
# Real Class for Elem 3: bathroom  Real Class for Elem 8: study  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.017 s
# prediction time: 0.003 s
# accuracy calculation time: 0.001 s
# Accuracy =  0.9
# Predicted Class for Elem 3: bedroom  Class for Elem 8: living_room  Class for elem 5: study
# Real Class for Elem 3: bedroom  Real Class for Elem 8: bedroom  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.017 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.89
# Predicted Class for Elem 3: bedroom  Class for Elem 8: living_room  Class for elem 5: living_room
# Real Class for Elem 3: bedroom  Real Class for Elem 8: living_room  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.019 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.89
# Predicted Class for Elem 3: study  Class for Elem 8: living_room  Class for elem 5: living_room
# Real Class for Elem 3: study  Real Class for Elem 8: living_room  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.018 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.88
# Predicted Class for Elem 3: bedroom  Class for Elem 8: bathroom  Class for elem 5: bedroom
# Real Class for Elem 3: bedroom  Real Class for Elem 8: bathroom  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.024 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.89
# Predicted Class for Elem 3: study  Class for Elem 8: study  Class for elem 5: bathroom
# Real Class for Elem 3: study  Real Class for Elem 8: study  Real Class for elem 5: bathroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.018 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.925
# Predicted Class for Elem 3: living_room  Class for Elem 8: living_room  Class for elem 5: living_room
# Real Class for Elem 3: living_room  Real Class for Elem 8: living_room  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.02 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.92
# Predicted Class for Elem 3: living_room  Class for Elem 8: study  Class for elem 5: bedroom
# Real Class for Elem 3: living_room  Real Class for Elem 8: study  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.02 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.935
# Predicted Class for Elem 3: study  Class for Elem 8: study  Class for elem 5: bedroom
# Real Class for Elem 3: study  Real Class for Elem 8: study  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.015 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.935
# Predicted Class for Elem 3: bathroom  Class for Elem 8: study  Class for elem 5: study
# Real Class for Elem 3: bathroom  Real Class for Elem 8: study  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.017 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.93
# Predicted Class for Elem 3: living_room  Class for Elem 8: bathroom  Class for elem 5: study
# Real Class for Elem 3: living_room  Real Class for Elem 8: bathroom  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.015 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.915
# Predicted Class for Elem 3: bathroom  Class for Elem 8: living_room  Class for elem 5: bathroom
# Real Class for Elem 3: bathroom  Real Class for Elem 8: living_room  Real Class for elem 5: bathroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.016 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.9
# Predicted Class for Elem 3: bathroom  Class for Elem 8: living_room  Class for elem 5: bathroom
# Real Class for Elem 3: bathroom  Real Class for Elem 8: bedroom  Real Class for elem 5: bathroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.018 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.935
# Predicted Class for Elem 3: living_room  Class for Elem 8: study  Class for elem 5: living_room
# Real Class for Elem 3: living_room  Real Class for Elem 8: study  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.017 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.915
# Predicted Class for Elem 3: bathroom  Class for Elem 8: bedroom  Class for elem 5: living_room
# Real Class for Elem 3: bathroom  Real Class for Elem 8: bedroom  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.015 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.93
# Predicted Class for Elem 3: living_room  Class for Elem 8: study  Class for elem 5: bedroom
# Real Class for Elem 3: living_room  Real Class for Elem 8: study  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.015 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.91
# Predicted Class for Elem 3: bedroom  Class for Elem 8: bathroom  Class for elem 5: bathroom
# Real Class for Elem 3: bedroom  Real Class for Elem 8: bathroom  Real Class for elem 5: bathroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.017 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.91
# Predicted Class for Elem 3: study  Class for Elem 8: bathroom  Class for elem 5: study
# Real Class for Elem 3: study  Real Class for Elem 8: bathroom  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.016 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.915
# Predicted Class for Elem 3: study  Class for Elem 8: living_room  Class for elem 5: study
# Real Class for Elem 3: study  Real Class for Elem 8: living_room  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.018 s
# prediction time: 0.003 s
# accuracy calculation time: 0.001 s
# Accuracy =  0.885
# Predicted Class for Elem 3: living_room  Class for Elem 8: bedroom  Class for elem 5: living_room
# Real Class for Elem 3: living_room  Real Class for Elem 8: bedroom  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.023 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.875
# Predicted Class for Elem 3: bathroom  Class for Elem 8: study  Class for elem 5: living_room
# Real Class for Elem 3: bathroom  Real Class for Elem 8: study  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.023 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.93
# Predicted Class for Elem 3: bedroom  Class for Elem 8: study  Class for elem 5: bedroom
# Real Class for Elem 3: bedroom  Real Class for Elem 8: study  Real Class for elem 5: bedroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.02 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.96
# Predicted Class for Elem 3: bathroom  Class for Elem 8: bedroom  Class for elem 5: study
# Real Class for Elem 3: bathroom  Real Class for Elem 8: bedroom  Real Class for elem 5: study
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.025 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.865
# Predicted Class for Elem 3: living_room  Class for Elem 8: bedroom  Class for elem 5: living_room
# Real Class for Elem 3: living_room  Real Class for Elem 8: bedroom  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.021 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.89
# Predicted Class for Elem 3: living_room  Class for Elem 8: living_room  Class for elem 5: bathroom
# Real Class for Elem 3: living_room  Real Class for Elem 8: bedroom  Real Class for elem 5: bathroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.02 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.885
# Predicted Class for Elem 3: study  Class for Elem 8: bathroom  Class for elem 5: bathroom
# Real Class for Elem 3: study  Real Class for Elem 8: bathroom  Real Class for elem 5: bathroom
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.02 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.89
# Predicted Class for Elem 3: living_room  Class for Elem 8: bathroom  Class for elem 5: living_room
# Real Class for Elem 3: living_room  Real Class for Elem 8: bathroom  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
# Generating for: FEATURES_12
# 2000
# Stored 2000 samples for FEATURES_12
# (1800, 10)
# (200, 10)
# ['bathtub' 'bed' 'bookshelf' 'chair' 'desk' 'dresser' 'night_stand' 'sofa'
#  'table' 'toilet']
# training time: 0.018 s
# prediction time: 0.002 s
# accuracy calculation time: 0.0 s
# Accuracy =  0.91
# Predicted Class for Elem 3: living_room  Class for Elem 8: study  Class for elem 5: living_room
# Real Class for Elem 3: living_room  Real Class for Elem 8: study  Real Class for elem 5: living_room
# ['bathroom' 'bedroom' 'living_room' 'study']
